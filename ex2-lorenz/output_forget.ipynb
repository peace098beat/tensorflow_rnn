# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
initial = np.load("lstm_basic/initial.npy")
initial_df = pd.DataFrame(initial, columns=["initial"])

# %%
output1 = np.load("lstm_forget0.25/output.npy")
output1_df = pd.DataFrame(output1, columns=["output (forget: 0.25)"], index=range(len(initial), len(initial) + len(output1)))
losses1_df = pd.DataFrame(np.load("lstm_forget0.25/losses.npy"), columns=["epoch", "loss (forget: 0.25)"])

# %%
output2 = np.load("lstm_forget0.5/output.npy")
output2_df = pd.DataFrame(output2, columns=["output (forget: 0.5)"], index=range(len(initial), len(initial) + len(output2)))
losses2_df = pd.DataFrame(np.load("lstm_forget0.5/losses.npy"), columns=["epoch", "loss (forget: 0.5)"])

# %%
output3 = np.load("lstm_basic/output.npy")
output3_df = pd.DataFrame(output3, columns=["output (forget: 1.0)"], index=range(len(initial), len(initial) + len(output3)))
losses3_df = pd.DataFrame(np.load("lstm_basic/losses.npy"), columns=["epoch", "loss (forget: 1.0)"])

# %%
train = np.load("train_data/normal.npy")
train_df = pd.DataFrame(train[:, 0], columns=["train"])

# %%
merged = pd.concat([train_df, initial_df, output1_df, output2_df, output3_df])
merged.plot(figsize=(15, 5), grid=True, style=["-", "-", "-", "-", "k--"])

# %%
merged = pd.merge(losses1_df, losses2_df)
merged = pd.merge(merged, losses3_df)
merged.plot(figsize=(15, 5), grid=True, logy=True, x="epoch")
